# %%
# !kaggle datasets download -d iamsouravbanerjee/world-population-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/iamsouravbanerjee/world-population-dataset
# License(s): other
# Downloading world-population-dataset.zip to /content
#   0% 0.00/15.7k [00:00<?, ?B/s]
# 100% 15.7k/15.7k [00:00<00:00, 21.4MB/s]

# %%
# !unzip world-population-dataset.zip
# Out:
# Archive:  world-population-dataset.zip
#   inflating: world_population.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('world_population.csv')
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 0         10694796         12486631         10752971      652230
# 1          3295066          2941651          2324731       28748
# 2         25518074         18739378         13795915     2381741
# 3            47818            32886            27075         199
# 4            53569            35611            19860         468
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 0            63.0587       1.0257                         0.52
# 1            98.8702       0.9957                         0.04
# 2            18.8531       1.0164                         0.56
# 3           222.4774       0.9831                         0.00
# 4           170.5641       1.0100                         0.00

# %% [markdown]
# #Basic information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
#  13  Area (km²)                   234 non-null    int64
#  14  Density (per km²)            234 non-null    float64
#  15  Growth Rate                  234 non-null    float64
#  16  World Population Percentage  234 non-null    float64
# dtypes: float64(3), int64(10), object(4)
# memory usage: 31.2+ KB

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# min       5.960000e+02     6.510000e+02     7.000000e+02     7.330000e+02
# 25%       3.931490e+05     3.272420e+05     2.641158e+05     2.296142e+05
# 50%       4.942770e+06     4.292907e+06     3.825410e+06     3.141146e+06
# 75%       1.915957e+07     1.576230e+07     1.186923e+07     9.826054e+06
# max       1.348191e+09     1.264099e+09     1.153704e+09     9.823725e+08
#
#        1970 Population    Area (km²)  Density (per km²)  Growth Rate  \
# count     2.340000e+02  2.340000e+02         234.000000   234.000000
# mean      1.578691e+07  5.814494e+05         452.127044     1.009577
# std       6.779509e+07  1.761841e+06        2066.121904     0.013385
# min       7.520000e+02  1.000000e+00           0.026100     0.912000
# 25%       1.559970e+05  2.650000e+03          38.417875     1.001775
# 50%       2.604830e+06  8.119950e+04          95.346750     1.007900
# 75%       8.817329e+06  4.304258e+05         238.933250     1.016950
# max       8.225344e+08  1.709824e+07       23172.266700     1.069100
#
#        World Population Percentage
# count                   234.000000
# mean                      0.427051
# std                       1.714977
# min                       0.000000
# 25%                       0.010000
# 50%                       0.070000
# 75%                       0.280000
# max                      17.880000

# %% [markdown]
# *So the analysis is majorly done for 3 categories i.e*
#
# *1.   Population analysis of India*
#
# *2.   Population analysis of Continents*
#
# *3.   Population analysis of the World*

# %% [markdown]
# #Population analysis of India

# %% [markdown]
# **Population trends in India 2000-2022**

# %%
india_data = df[df['Country/Territory'] == 'India']

india_population = pd.DataFrame({
    'Year': ['2000', '2010', '2015', '2020', '2022'],
    'Population': [india_data['2000 Population'].values[0],
                   india_data['2010 Population'].values[0],
                   india_data['2015 Population'].values[0],
                   india_data['2020 Population'].values[0],
                   india_data['2022 Population'].values[0]]
})

fig = px.line(india_population,
              x='Year',
              y='Population',
              title='Population Trend in India from 2000 to 2022',
              labels={'Year': 'Year', 'Population': 'Population'},
              markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4f2f8bf6-fef2-4b57-ba16-c6e330bbe9c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f2f8bf6-fef2-4b57-ba16-c6e330bbe9c9")) {                    Plotly.newPlot(                        "4f2f8bf6-fef2-4b57-ba16-c6e330bbe9c9",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003ePopulation=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2000","2010","2015","2020","2022"],"xaxis":"x","y":[1059633675,1240613620,1322866505,1396387127,1417173173],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar": ...

# %% [markdown]
# **Growth rate of India's population over different decades**

# %%
df_pr = df[df['Country/Territory'] == 'India']

india_population = pd.DataFrame({
    'Year': ['1970','1980','1990','2000','2010','2015','2020','2022'],
    'Population': [df_pr['1970 Population'].values[0],df_pr['1980 Population'].values[0],
                   df_pr['1990 Population'].values[0],df_pr['2000 Population'].values[0],
                   df_pr['2010 Population'].values[0],df_pr['2015 Population'].values[0],
                   df_pr['2020 Population'].values[0],df_pr['2022 Population'].values[0]]
 })

growth_rate = [0]

for i in range(1, len(india_population)):
    growth = (india_population['Population'].iloc[i] - india_population['Population'].iloc[i-1]) / india_population['Population'].iloc[i-1] * 100
    growth_rate.append(growth)

india_population['Growth Rate'] = growth_rate

fig = px.line(india_population,x='Year',y='Growth Rate',title='Growth rate of India\'s population over different decades',markers='True')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2a774886-e45e-43c5-bee4-ddee4cd75086" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a774886-e45e-43c5-bee4-ddee4cd75086")) {                    Plotly.newPlot(                        "2a774886-e45e-43c5-bee4-ddee4cd75086",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eGrowth Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["1970","1980","1990","2000","2010","2015","2020","2022"],"xaxis":"x","y":[0.0,24.991346881179744,24.916289826511587,21.733705493167452,17.07948220879258,6.63001628178159,5.557675073192665,1.4885589818245295],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay ...

# %% [markdown]
# **India’s population density compare to other countries**

# %%
df_pr = df[['Country/Territory', 'Area (km²)', 'Density (per km²)']]

fig = px.scatter(df_pr,
                 x='Area (km²)',
                 y='Density (per km²)',
                 hover_name='Country/Territory',
                 title="Population Density vs Area Size for Different Countries",
                 labels={'Density (per km²)': 'Population Density (per km²)', 'Area (km²)': 'Area Size (km²)'},
                 size='Density (per km²)', color='Density (per km²)')

#Highlighting India
fig.add_annotation(x=df_pr[df_pr['Country/Territory'] == 'India']['Area (km²)'].values[0],
                   y=df_pr[df_pr['Country/Territory'] == 'India']['Density (per km²)'].values[0],
                   text="India",
                   showarrow=True, arrowhead=1, ax=50, ay=-50)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ce69a6c1-96b7-4ee1-afe8-e1a3e556588c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce69a6c1-96b7-4ee1-afe8-e1a3e556588c")) {                    Plotly.newPlot(                        "ce69a6c1-96b7-4ee1-afe8-e1a3e556588c",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eArea Size (km\u00b2)=%{x}\u003cbr\u003ePopulation Density (per km\u00b2)=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Albania","Algeria","American Samoa","Andorra","Angola","Anguilla","Antigua and Barbuda","Argentina","Armenia","Aruba","Australia","Austria","Azerbaijan","Bahamas","Bahrain","Bangladesh","Barbados","Belarus","Belgium","Belize","Benin","Bermuda","Bhutan","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","British Virgin Islands","Brunei","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Cape Verde","Cayman Islands","Central African Republic","Chad","Chile","China","Colombia","Comoros","Cook Islands","Costa Rica","Croatia","Cuba","Curacao","Cyprus","Czech Republic","Denmark","Djibouti","Dominica","Dominican Republic","DR Congo","Ecuador","Egypt","El Salvador","Equatorial Guinea","Eritrea","Estonia","Eswatini","Ethiopia","Falkland Islands","Faroe Islands","Fiji","Finland","France","French Guiana","French Polynesia","Gabon","Gambia","Georgia","Germany","Ghana","Gibraltar","Greece","Greenland","Grenada","Guadeloupe","Guam","Guatemala","Guernsey","Guinea","Guinea-Bissau","Guyana","Haiti","Honduras","Hong Kong","Hungary","Iceland","India","Indonesia","Iran","Iraq","Ireland","Isle of Man","Israel","Italy","Ivory Coast","Jamaica","Japan","Jersey","Jordan","Kazakhstan","Kenya","Kiribati","Kuwait","Kyrgyzstan","Laos","Latvia","Lebanon","Lesotho","Liberia","Libya","Liechtenstein","Lithuania","Luxembourg","Macau","Madagascar","Malawi","Malaysia","Maldives","Mali","Malta","Marshall Islands","Martinique","Mauritania","Mauritius","Mayotte","Mexico","Micronesia","Moldova","Monaco","Mongolia","Montenegro","Montserrat","Morocco","Mozambique","Myanmar","Namibia","Nauru","Nepal","Netherlands","New Caledonia","New Zealand","Nicaragua","Niger","Nigeria","Niue","North Korea","North Macedonia","Northern Mariana Islands","Norway","Oman","Pakistan","Palau","Palestine","Panama","Papua New Guinea","Paraguay","Peru","Philippines","Poland","Portugal","Puerto Rico","Qatar","Republic of the Congo","Reunion","Romania","Russia","Rwanda","Saint Barthelemy","Saint Kitts and Nevis","Saint Lucia","Saint Martin","Saint Pierre and Miquelon","Saint Vincent and the Grenadines","Samoa","San Marino","Sao Tome and Principe","Saudi Arabia","Senegal","Serbia","Seychelles","Sierra Leone","Singapore","Sint Maarten","Slovakia","Slovenia","Solomon Islands","Somalia","South Africa","South Korea","South Sudan","Spain","Sri Lanka","Sudan","Suriname","Sweden","Switzerland","Syria","Taiwan","Tajikistan","Tanzania","Thailand","Timor-Leste","Togo","Tokelau","Tonga","Trinidad and Tobago","Tunisia","Turkey","Turkmenistan","Turks and Caicos Islands","Tuvalu","Uganda","Ukraine","United Arab Emirates","United Kingdom","United States","United States Virgin Islands","Uruguay","Uzbekistan","Vanuatu","Vatican City","Venezuela","Vietnam","Wallis and Futuna","Western Sahara","Yemen","Zambia","Zimbabwe"],"legendgroup":"","marker":{"color":[63.0587,98.8702,18.8531,222.4774,170.5641,28.5466,174.2527,212.1335,16.3683,93.4831,591.3611,3.4032,106.5877,119.6082,29.4043,1924.4876,1160.035,654.9651,45.9295,381.8111,17.6466,118.5635,1188.5926,20.3796,11.1272,63.1437,4.5194,25.2841,207.3179,77.8841,61.1654,83.0641,463.0874,92.6221,58.7128,3.8513,147.0739,260.25,8.9555,13.8032,25.9274,146.8 ...

# %% [markdown]
# #Population analysis of Continents

# %% [markdown]
#  **Population distributed across the continents in 2022**

# %%
df_plot = df[['Country/Territory', 'Continent', '2022 Population']]

# Group by continent to get the total population per continent
continent_population = df_plot.groupby('Continent')['2022 Population'].sum().reset_index()

# Stacked bar chart
fig = px.bar(df_plot,
             x='Continent',
             y='2022 Population',
             color='Country/Territory',
             title="Population Distribution Across Continents in 2022",
             labels={'2022 Population': 'Population (in billions)', 'Continent': 'Continent'},
             text_auto=True)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4c0644a8-a35c-41f6-8772-82fafea1dd03" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c0644a8-a35c-41f6-8772-82fafea1dd03")) {                    Plotly.newPlot(                        "4c0644a8-a35c-41f6-8772-82fafea1dd03",                        [{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=Afghanistan\u003cbr\u003eContinent=%{x}\u003cbr\u003ePopulation (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Asia"],"xaxis":"x","y":[41128771],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=Albania\u003cbr\u003eContinent=%{x}\u003cbr\u003ePopulation (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Albania","offsetgroup":"Albania","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Europe"],"xaxis":"x","y":[2842321],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=Algeria\u003cbr\u003eContinent=%{x}\u003cbr\u003ePopulation (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Africa"],"xaxis":"x","y":[44903225],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=American Samoa\u003cbr\u003eContinent=%{x}\u003cbr\u003ePopulation (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"American Samoa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"American Samoa","offsetgroup":"American Samoa","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Oceania"],"xaxis":"x","y":[44273],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=Andorra\u003cbr\u003eContinent=%{x}\u003cbr\u003ePopulation (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andorra","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Andorra","offsetgroup":"Andorra","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Europe"],"xaxis":"x","y":[79824],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=Angola\u003cbr\u003eContinent=%{x}\u003cbr\u003ePopulation (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Angola","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Angola","offsetgroup":"Angola","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Africa"],"xaxis":"x","y":[35588987],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=Anguilla\u003cbr\u003eContinent=%{x}\u003cbr\u003ePopulation (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Anguilla","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Anguilla","offsetgroup":"Anguilla","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["North America"],"xaxis":"x","y":[15857],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=Antigua and Barbuda\u003cbr\u003eContinent=%{x}\u003cbr\u003ePopulation (in billions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Antigua and Barbuda","marker":{"co ...

# %% [markdown]
# **Continent has the highest population density**

# %%
df_pr = df.groupby('Continent')['Density (per km²)'].sum().reset_index()

fig = px.bar(df_pr,x='Continent',y='Density (per km²)',title='Continent has the highest population density')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="da472d21-498f-4354-90f2-3b5fe3c1681d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da472d21-498f-4354-90f2-3b5fe3c1681d")) {                    Plotly.newPlot(                        "da472d21-498f-4354-90f2-3b5fe3c1681d",                        [{"alignmentgroup":"True","hovertemplate":"Continent=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Africa","Asia","Europe","North America","Oceania","South America"],"xaxis":"x","y":[7127.7158,51251.2068,33166.2371,10910.4703,3048.4905,293.6077],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2} ...

# %% [markdown]
# **Correlation between growth rate, area, and population by continent**

# %%
df_corr = df[['Continent', '2022 Population', 'Area (km²)', 'Growth Rate']]

# Group by continent and aggregate data for correlation analysis
df_grouped = df_corr.groupby('Continent').agg({
    '2022 Population': 'sum',
    'Area (km²)': 'sum',
    'Growth Rate': 'mean'
}).reset_index()

# Calculate the correlation matrix for the grouped data
corr_matrix = df_grouped[['2022 Population', 'Area (km²)', 'Growth Rate']].corr()

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='viridis', linewidths=0.5)
plt.title('Correlation Between Growth Rate, Area, and Population by Continent')
plt.show()

# %% [markdown]
# **Relationship between population growth rate and population size by continent**

# %%
df_pr = df.groupby('Continent').agg({
    '2022 Population': 'sum',
    'Area (km²)': 'sum',
    'Growth Rate': 'mean'
}).reset_index()

fig = px.scatter(df_pr,x='2022 Population',y='Growth Rate',color='Continent',title='Relationship between population growth rate and population size by continent')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ee8d340c-5f02-42ca-a0fa-367d15b4ecbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee8d340c-5f02-42ca-a0fa-367d15b4ecbe")) {                    Plotly.newPlot(                        "ee8d340c-5f02-42ca-a0fa-367d15b4ecbe",                        [{"hovertemplate":"Continent=Africa\u003cbr\u003e2022 Population=%{x}\u003cbr\u003eGrowth Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Africa","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Africa","orientation":"v","showlegend":true,"x":[1426730932],"xaxis":"x","y":[1.021243859649123],"yaxis":"y","type":"scatter"},{"hovertemplate":"Continent=Asia\u003cbr\u003e2022 Population=%{x}\u003cbr\u003eGrowth Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Asia","orientation":"v","showlegend":true,"x":[4721383274],"xaxis":"x","y":[1.009384],"yaxis":"y","type":"scatter"},{"hovertemplate":"Continent=Europe\u003cbr\u003e2022 Population=%{x}\u003cbr\u003eGrowth Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Europe","orientation":"v","showlegend":true,"x":[743147538],"xaxis":"x","y":[1.002256],"yaxis":"y","type":"scatter"},{"hovertemplate":"Continent=North America\u003cbr\u003e2022 Population=%{x}\u003cbr\u003eGrowth Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"North America","orientation":"v","showlegend":true,"x":[600296136],"xaxis":"x","y":[1.004175],"yaxis":"y","type":"scatter"},{"hovertemplate":"Continent=Oceania\u003cbr\u003e2022 Population=%{x}\u003cbr\u003eGrowth Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oceania","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Oceania","orientation":"v","showlegend":true,"x":[45038554],"xaxis":"x","y":[1.0073826086956523],"yaxis":"y","type":"scatter"},{"hovertemplate":"Continent=South America\u003cbr\u003e2022 Population=%{x}\u003cbr\u003eGrowth Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South America","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"South America","orientation":"v","showlegend":true,"x":[436816608],"xaxis":"x","y":[1.0079571428571428],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}], ...

# %% [markdown]
# **Population growth rate of each continent over time**

# %% [markdown]
# **Population distribution of countries within a continent variation**

# %%
df_pr = df[df['Continent'] == 'Asia'][['Country/Territory','2022 Population']]
# Filter the DataFrame based on the condition and then select the '2022 Population' column.
fig = px.box(df_pr,y='2022 Population',title='Population distribution of countries within a continent variation')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0a2b2677-177d-4d81-9afc-83d8ab8a9b3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a2b2677-177d-4d81-9afc-83d8ab8a9b3f")) {                    Plotly.newPlot(                        "0a2b2677-177d-4d81-9afc-83d8ab8a9b3f",                        [{"alignmentgroup":"True","hovertemplate":"2022 Population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[41128771,2780469,10358074,1472233,171186372,782455,449002,16767842,1425887337,3744385,7488865,1417173173,275501339,88550570,44496122,9038309,123951692,11285869,19397998,4268873,6630623,7529475,5489739,695168,33938221,523787,3398366,54179306,30547580,26069416,4576298,235824862,5250072,115559009,2695122,36408820,5975689,51815810,21832143,22125249,23893394,9952787,71697030,1341296,85341241,6430770,9441129,34627652,98186856,33696614],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{ ...

# %% [markdown]
# **Percentage distribution of the world’s population continentwise**

# %%
df_pr = df.groupby('Continent')['2022 Population'].sum().reset_index()
df_pr

fig = px.pie(df_pr,values='2022 Population',names='Continent',title='Percentage distribution of the world’s population continentwise')
fig.update_layout(width=900,height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d634194d-df5a-41de-9fda-1f6e2b3d2792" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d634194d-df5a-41de-9fda-1f6e2b3d2792")) {                    Plotly.newPlot(                        "d634194d-df5a-41de-9fda-1f6e2b3d2792",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Continent=%{label}\u003cbr\u003e2022 Population=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Africa","Asia","Europe","North America","Oceania","South America"],"legendgroup":"","name":"","showlegend":true,"values":[1426730932,4721383274,743147538,600296136,45038554,436816608],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"s ...

# %% [markdown]
# **Correlation between growth rate, area, and population by continent**

# %%
df_pr = df.groupby('Continent').agg({
        '2022 Population':'sum',
        'Area (km²)':'sum',
        'Growth Rate':'mean'
        }).reset_index()

df_pr= df_pr.drop('Continent',axis = 1)

df_pr.corr()

fig = px.imshow(df_pr.corr(),title='Correlation between growth rate, area, and population by continent',
                         labels=dict(x='Variables', y='Variables', color='Correlation Coefficient'),)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1de2e9cc-d99b-4187-b397-00ebab83f086" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1de2e9cc-d99b-4187-b397-00ebab83f086")) {                    Plotly.newPlot(                        "1de2e9cc-d99b-4187-b397-00ebab83f086",                        [{"coloraxis":"coloraxis","name":"0","x":["2022 Population","Area (km\u00b2)","Growth Rate"],"y":["2022 Population","Area (km\u00b2)","Growth Rate"],"z":[[1.0,0.7245853871199914,0.22599960418651968],[0.7245853871199914,1.0,0.39991375651806915],[0.22599960418651968,0.39991375651806915,1.0]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"Variables: %{x}\u003cbr\u003eVariables: %{y}\u003cbr\u003eCorrelation Coefficient: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity" ...

# %% [markdown]
# #Population analysis of World

# %%
df_pr = df[['Country/Territory','2022 Population']]
df_pr.sort_values(by='2022 Population',ascending=False,inplace=True)
px.bar(df_pr.head(10),x='Country/Territory',y='2022 Population',title='Top 10 Population Country')
# Out:
# <ipython-input-17-9c1642cddf3c>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8a8383db-2dbe-427c-93df-db136678d01d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a8383db-2dbe-427c-93df-db136678d01d")) {                    Plotly.newPlot(                        "8a8383db-2dbe-427c-93df-db136678d01d",                        [{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=%{x}\u003cbr\u003e2022 Population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["China","India","United States","Indonesia","Pakistan","Nigeria","Brazil","Bangladesh","Russia","Mexico"],"xaxis":"x","y":[1425887337,1417173173,338289857,275501339,235824862,218541212,215313498,171186372,144713314,127504125],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"col ...

# %%
px.bar(df_pr.tail(10),x='Country/Territory',y='2022 Population',title='Bottom 10 Population Country')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="42c428e8-e4d0-4ca9-a30f-1e6eae74ac0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42c428e8-e4d0-4ca9-a30f-1e6eae74ac0b")) {                    Plotly.newPlot(                        "42c428e8-e4d0-4ca9-a30f-1e6eae74ac0b",                        [{"alignmentgroup":"True","hovertemplate":"Country\u002fTerritory=%{x}\u003cbr\u003e2022 Population=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Nauru","Wallis and Futuna","Tuvalu","Saint Barthelemy","Saint Pierre and Miquelon","Montserrat","Falkland Islands","Niue","Tokelau","Vatican City"],"xaxis":"x","y":[12668,11572,11312,10967,5862,4390,3780,1934,1871,510],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"# ...

# %% [markdown]
# **World population percentage vary among the top 5 most populous countries**

# %%
df_pr = df[['Country/Territory','2022 Population']]
df_pr.sort_values(by='2022 Population',ascending=False,inplace=True)
fig = px.pie(df_pr.head(5),values='2022 Population',names='Country/Territory',title='World population percentage vary among the top 5 most populous countries')
fig.show()
# Out:
# <ipython-input-19-1e600b03d782>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cf7198b8-dad8-4e90-b131-be1b232e919c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf7198b8-dad8-4e90-b131-be1b232e919c")) {                    Plotly.newPlot(                        "cf7198b8-dad8-4e90-b131-be1b232e919c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Country\u002fTerritory=%{label}\u003cbr\u003e2022 Population=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["China","India","United States","Indonesia","Pakistan"],"legendgroup":"","name":"","showlegend":true,"values":[1425887337,1417173173,338289857,275501339,235824862],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpol ...

# %% [markdown]
# **Relationship between area size and population for different countries**

# %%
df_pr = df[['Country/Territory','2022 Population','Area (km²)']]

fig = px.scatter(
    df_pr,
    x='2022 Population',
    y='Area (km²)',
    color='Country/Territory',
    size='Area (km²)',  # Changed 'Area' to 'Area (km²)'
    size_max=20,
    hover_name='Country/Territory',
    title='Relationship between Area Size and Population (2022)',
    labels={
        '2022 Population': 'Population (in billions)',
        'Area (km²)': 'Area (in km²)',
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1ec4db59-419f-434e-8b4f-870164211e05" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ec4db59-419f-434e-8b4f-870164211e05")) {                    Plotly.newPlot(                        "1ec4db59-419f-434e-8b4f-870164211e05",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Afghanistan\u003cbr\u003ePopulation (in billions)=%{x}\u003cbr\u003eArea (in km\u00b2)=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan"],"legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[652230],"sizemode":"area","sizeref":42745.605,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[41128771],"xaxis":"x","y":[652230],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Albania\u003cbr\u003ePopulation (in billions)=%{x}\u003cbr\u003eArea (in km\u00b2)=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania"],"legendgroup":"Albania","marker":{"color":"#EF553B","size":[28748],"sizemode":"area","sizeref":42745.605,"symbol":"circle"},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":[2842321],"xaxis":"x","y":[28748],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Algeria\u003cbr\u003ePopulation (in billions)=%{x}\u003cbr\u003eArea (in km\u00b2)=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Algeria"],"legendgroup":"Algeria","marker":{"color":"#00cc96","size":[2381741],"sizemode":"area","sizeref":42745.605,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[44903225],"xaxis":"x","y":[2381741],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=American Samoa\u003cbr\u003ePopulation (in billions)=%{x}\u003cbr\u003eArea (in km\u00b2)=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["American Samoa"],"legendgroup":"American Samoa","marker":{"color":"#ab63fa","size":[199],"sizemode":"area","sizeref":42745.605,"symbol":"circle"},"mode":"markers","name":"American Samoa","orientation":"v","showlegend":true,"x":[44273],"xaxis":"x","y":[199],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Andorra\u003cbr\u003ePopulation (in billions)=%{x}\u003cbr\u003eArea (in km\u00b2)=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Andorra"],"legendgroup":"Andorra","marker":{"color":"#FFA15A","size":[468],"sizemode":"area","sizeref":42745.605,"symbol":"circle"},"mode":"markers","name":"Andorra","orientation":"v","showlegend":true,"x":[79824],"xaxis":"x","y":[468],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Angola\u003cbr\u003ePopulation (in billions)=%{x}\u003cbr\u003eArea (in km\u00b2)=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Angola"],"legendgroup":"Angola","marker":{"color":"#19d3f3","size":[1246700],"sizemode":"area","sizeref":42745.605,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[35588987],"xaxis":"x","y":[1246700],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Anguilla\u003cbr\u003ePopulation (in billions)=%{x}\u0 ...

# %% [markdown]
# **Impact of geographical factors like area and density on the country growth**

# %%
df_pr = df[['Country/Territory','Area (km²)','Density (per km²)','Growth Rate']]
fig = px.scatter_3d(df_pr,x='Area (km²)',y='Density (per km²)',z='Growth Rate',color='Country/Territory',title='Impact of geographical factors like area and density on the country growth')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="901f5499-0538-4446-be50-156bd74c841c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("901f5499-0538-4446-be50-156bd74c841c")) {                    Plotly.newPlot(                        "901f5499-0538-4446-be50-156bd74c841c",                        [{"hovertemplate":"Country\u002fTerritory=Afghanistan\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003eGrowth Rate=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Afghanistan","scene":"scene","showlegend":true,"x":[652230],"y":[63.0587],"z":[1.0257],"type":"scatter3d"},{"hovertemplate":"Country\u002fTerritory=Albania\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003eGrowth Rate=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Albania","scene":"scene","showlegend":true,"x":[28748],"y":[98.8702],"z":[0.9957],"type":"scatter3d"},{"hovertemplate":"Country\u002fTerritory=Algeria\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003eGrowth Rate=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"Algeria","scene":"scene","showlegend":true,"x":[2381741],"y":[18.8531],"z":[1.0164],"type":"scatter3d"},{"hovertemplate":"Country\u002fTerritory=American Samoa\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003eGrowth Rate=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"American Samoa","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"American Samoa","scene":"scene","showlegend":true,"x":[199],"y":[222.4774],"z":[0.9831],"type":"scatter3d"},{"hovertemplate":"Country\u002fTerritory=Andorra\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003eGrowth Rate=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andorra","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"Andorra","scene":"scene","showlegend":true,"x":[468],"y":[170.5641],"z":[1.01],"type":"scatter3d"},{"hovertemplate":"Country\u002fTerritory=Angola\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003eGrowth Rate=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Angola","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"Angola","scene":"scene","showlegend":true,"x":[1246700],"y":[28.5466],"z":[1.0315],"type":"scatter3d"},{"hovertemplate":"Country\u002fTerritory=Anguilla\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003eGrowth Rate=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Anguilla","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"Anguilla","scene":"scene","showlegend":true,"x":[91],"y":[174.2527],"z":[1.0066],"type":"scatter3d"},{"hovertemplate":"Country\u002fTerritory=Antigua and Barbuda\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003eGrowth Rate=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Antigua and Barbuda","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"Antigua and Barbuda","scene":"scene","showlegend":true,"x":[442],"y":[212.1335],"z":[1.0058],"type":"scatter3d"},{"hovertemplate":"Country\u002fTerritory=Argentina\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003eGrowth Rate=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","m ...

# %% [markdown]
# **Correlation between different population metrics**

# %%
df_numeric = df.select_dtypes(include=['float64', 'int64'])
df_pr=df_numeric.corr()
df_pr.drop('Rank',axis=0,inplace=True)
df_pr.drop('Rank',axis=1,inplace=True)
df_pr.drop('World Population Percentage',axis=0,inplace=True)
df_pr.drop('World Population Percentage',axis=1,inplace=True)
sns.heatmap(df_pr,cmap='viridis')
plt.show()

# %% [markdown]
# **Population density vary with country size globally**

# %%
df_pr = df[['Country/Territory','2022 Population','Area (km²)','Density (per km²)']]
fig = px.scatter(df_pr,x='Area (km²)',y='Density (per km²)',title='Population density vary with country size globally',
                 hover_name = 'Country/Territory',size = '2022 Population',color = 'Country/Territory')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3a00860f-59bc-4892-9995-99c3d4334bd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a00860f-59bc-4892-9995-99c3d4334bd7")) {                    Plotly.newPlot(                        "3a00860f-59bc-4892-9995-99c3d4334bd7",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Afghanistan\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003e2022 Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan"],"legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[41128771],"sizemode":"area","sizeref":3564718.3425,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[652230],"xaxis":"x","y":[63.0587],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Albania\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003e2022 Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania"],"legendgroup":"Albania","marker":{"color":"#EF553B","size":[2842321],"sizemode":"area","sizeref":3564718.3425,"symbol":"circle"},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":[28748],"xaxis":"x","y":[98.8702],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Algeria\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003e2022 Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Algeria"],"legendgroup":"Algeria","marker":{"color":"#00cc96","size":[44903225],"sizemode":"area","sizeref":3564718.3425,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[2381741],"xaxis":"x","y":[18.8531],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=American Samoa\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003e2022 Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["American Samoa"],"legendgroup":"American Samoa","marker":{"color":"#ab63fa","size":[44273],"sizemode":"area","sizeref":3564718.3425,"symbol":"circle"},"mode":"markers","name":"American Samoa","orientation":"v","showlegend":true,"x":[199],"xaxis":"x","y":[222.4774],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Andorra\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003e2022 Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Andorra"],"legendgroup":"Andorra","marker":{"color":"#FFA15A","size":[79824],"sizemode":"area","sizeref":3564718.3425,"symbol":"circle"},"mode":"markers","name":"Andorra","orientation":"v","showlegend":true,"x":[468],"xaxis":"x","y":[170.5641],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Angola\u003cbr\u003eArea (km\u00b2)=%{x}\u003cbr\u003eDensity (per km\u00b2)=%{y}\u003cbr\u003e2022 Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Angola"],"legendgroup":"Angola","marker":{"color":"#19d3f3","size":[35588987],"sizemode":"area","sizeref":3564718.3425,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[1246700],"xaxis":"x","y":[2 ...

# %%
# Out:
# <ipython-input-30-b1868c4a9145>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6cd93253-06f5-4a40-94b7-0a1a7baf0690" class="plotly-graph-div" style="height:600px; width:950px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cd93253-06f5-4a40-94b7-0a1a7baf0690")) {                    Plotly.newPlot(                        "6cd93253-06f5-4a40-94b7-0a1a7baf0690",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Afghanistan\u003cbr\u003eCountry Size (Area in km\u00b2)=%{x}\u003cbr\u003ePopulation Density (per km\u00b2)=%{y}\u003cbr\u003eTotal Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan"],"legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[41128771],"sizemode":"area","sizeref":1584319.2633333334,"symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.6},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[652230],"xaxis":"x","y":[63.05869248577956],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Albania\u003cbr\u003eCountry Size (Area in km\u00b2)=%{x}\u003cbr\u003ePopulation Density (per km\u00b2)=%{y}\u003cbr\u003eTotal Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Albania"],"legendgroup":"Albania","marker":{"color":"#EF553B","size":[2842321],"sizemode":"area","sizeref":1584319.2633333334,"symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.6},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":[28748],"xaxis":"x","y":[98.87021705857799],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Algeria\u003cbr\u003eCountry Size (Area in km\u00b2)=%{x}\u003cbr\u003ePopulation Density (per km\u00b2)=%{y}\u003cbr\u003eTotal Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Algeria"],"legendgroup":"Algeria","marker":{"color":"#00cc96","size":[44903225],"sizemode":"area","sizeref":1584319.2633333334,"symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.6},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[2381741],"xaxis":"x","y":[18.853109972914773],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=American Samoa\u003cbr\u003eCountry Size (Area in km\u00b2)=%{x}\u003cbr\u003ePopulation Density (per km\u00b2)=%{y}\u003cbr\u003eTotal Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["American Samoa"],"legendgroup":"American Samoa","marker":{"color":"#ab63fa","size":[44273],"sizemode":"area","sizeref":1584319.2633333334,"symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.6},"mode":"markers","name":"American Samoa","orientation":"v","showlegend":true,"x":[199],"xaxis":"x","y":[222.47738693467338],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry\u002fTerritory=Andorra\u003cbr\u003eCountry Size (Area in km\u00b2)=%{x}\u003cbr\u003ePopulation Density (per km\u00b2)=%{y}\u003cbr\u003eTotal Population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Andorra"],"legendgroup":"Andorra","marker":{"color":"#FFA15A","size":[79824],"sizemode":"area","sizeref":1584319.2633333334,"symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.6},"mode":"markers","name":"Andorra","orientation":"v","showlegend":true,"x":[468],"xaxis":"x","y":[170.56410256410257],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\ ...

# %% [markdown]
# **Population density distribution across all countries**

# %%
df_pr = df[['Country/Territory','Density (per km²)']]
fig = px.histogram(df_pr,x='Density (per km²)',title='Population density distribution across all countries',
                   hover_name='Country/Territory',color='Country/Territory',
                   labels={'Density (per km²)':'Population Density (per km²)','Country/Territory':'Countries'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a9b1e00b-91b6-4a4b-b073-61cce49afeb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9b1e00b-91b6-4a4b-b073-61cce49afeb9")) {                    Plotly.newPlot(                        "a9b1e00b-91b6-4a4b-b073-61cce49afeb9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Countries=Afghanistan\u003cbr\u003ePopulation Density (per km\u00b2)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"x":[63.0587],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Countries=Albania\u003cbr\u003ePopulation Density (per km\u00b2)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Albania","offsetgroup":"Albania","orientation":"v","showlegend":true,"x":[98.8702],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Countries=Algeria\u003cbr\u003ePopulation Density (per km\u00b2)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"x":[18.8531],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Countries=American Samoa\u003cbr\u003ePopulation Density (per km\u00b2)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"American Samoa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"American Samoa","offsetgroup":"American Samoa","orientation":"v","showlegend":true,"x":[222.4774],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Countries=Andorra\u003cbr\u003ePopulation Density (per km\u00b2)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Andorra","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Andorra","offsetgroup":"Andorra","orientation":"v","showlegend":true,"x":[170.5641],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Countries=Angola\u003cbr\u003ePopulation Density (per km\u00b2)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Angola","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Angola","offsetgroup":"Angola","orientation":"v","showlegend":true,"x":[28.5466],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Countries=Anguilla\u003cbr\u003ePopulation Density (per km\u00b2)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Anguilla","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Anguilla","offsetgroup":"Anguilla","orientation":"v","showlegend":true,"x":[174.2527],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Countries=Antigua and Barbuda\u003cbr\u003ePopulation Density (per km\u00b2)=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Antigua and Barbuda","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Antigua and Barbuda","offsetgroup":"Antigua and Barbuda","orientation":"v","showlegend":true,"x":[212.1335],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Countries=Argentina\u003cbr\u003ePopulation Density (per km ...

# %%
for country in df_top_5['Country/Territory'].unique():
    country_data = df_top_5[df_top_5['Country/Territory'] == country]
    fig.add_trace(go.Scatter(
        x=[1970, 1980, 1990, 2000, 2010, 2015, 2020, 2022],
        y=country_data[['1970 Population', '1980 Population', '1990 Population',
                        '2000 Population', '2010 Population', '2015 Population',
                        '2020 Population', '2022 Population']].values[0],
        mode='lines+markers',
        name=country,
        line=dict(width=2),
        marker=dict(size=6)
    ))

# Update layout to set the title, axis titles, and legend title
fig.update_layout(
    title_text='Population Growth Trends of the Top 5 Most Populous Countries (1970-2022)',
    xaxis_title='Year',
    yaxis_title='Population',
    legend_title='Country/Territory'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e9331d84-f8cf-4141-a97f-a393b0eb6c81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9331d84-f8cf-4141-a97f-a393b0eb6c81")) {                    Plotly.newPlot(                        "e9331d84-f8cf-4141-a97f-a393b0eb6c81",                        [{"line":{"width":2},"marker":{"size":6},"mode":"lines+markers","name":"China","x":[1970,1980,1990,2000,2010,2015,2020,2022],"y":[822534450,982372466,1153704252,1264099069,1348191368,1393715448,1424929781,1425887337],"type":"scatter"},{"line":{"width":2},"marker":{"size":6},"mode":"lines+markers","name":"India","x":[1970,1980,1990,2000,2010,2015,2020,2022],"y":[557501301,696828385,870452165,1059633675,1240613620,1322866505,1396387127,1417173173],"type":"scatter"},{"line":{"width":2},"marker":{"size":6},"mode":"lines+markers","name":"United States","x":[1970,1980,1990,2000,2010,2015,2020,2022],"y":[200328340,223140018,248083732,282398554,311182845,324607776,335942003,338289857],"type":"scatter"},{"line":{"width":2},"marker":{"size":6},"mode":"lines+markers","name":"Indonesia","x":[1970,1980,1990,2000,2010,2015,2020,2022],"y":[115228394,148177096,182159874,214072421,244016173,259091970,271857970,275501339],"type":"scatter"},{"line":{"width":2},"marker":{"size":6},"mode":"lines+markers","name":"Pakistan","x":[1970,1980,1990,2000,2010,2015,2020,2022],"y":[59290872,80624057,115414069,154369924,194454498,210969298,227196741,235824862],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0 ...
